# %%
import pandas as pd

sample = pd.read_csv("DBSCAN_SAMPLE.csv")
print(sample)
sample = sample.dropna()
sample = sample.drop_duplicates()
print(sample)
# Out:
#             X0        X1
# 0     0.187219 -0.584775
# 1    -0.484007  0.226619
# 2    -0.607691  0.279420
# 3     0.829826  0.481182
# 4     0.479004  0.384539
# ...        ...       ...
# 5995  1.116034  1.052029
# 5996  1.250111  1.327820
# 5997  1.118042  1.088597
# 5998  1.346323  1.206325
# 5999  1.207569  1.179452
#
# [6000 rows x 2 columns]
#             X0        X1
# 0     0.187219 -0.584775
# 1    -0.484007  0.226619
# 2    -0.607691  0.279420
# 3     0.829826  0.481182
# 4     0.479004  0.384539
# ...        ...       ...
# 5995  1.116034  1.052029
# 5996  1.250111  1.327820
# 5997  1.118042  1.088597
# 5998  1.346323  1.206325
# 5999  1.207569  1.179452
#
# [6000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
X = sample.iloc[:, 0].values.reshape(-1, 1)
Y = sample.iloc[:, 1].values.reshape(-1, 1)
plt.scatter(X, Y, color='blue')
plt.show()

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps = 0.1, min_samples = 10)
X = sample.iloc[:, 0:2].values.reshape(-1, 2)
y_pred = dbscan.fit_predict(X)
plt.title("eps = 0.1, min_samples = 10")
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %%
dbscan = DBSCAN(eps = 0.1)
X = sample.iloc[:, 0:2].values.reshape(-1, 2)
y_pred = dbscan.fit_predict(X)
plt.title("eps = 0.1")
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %%
dbscan = DBSCAN()
X = sample.iloc[:, 0:2].values.reshape(-1, 2)
y_pred = dbscan.fit_predict(X)
plt.title("default parameter")
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

# %%
import pandas as pd
task = pd.read_csv("DBSCAN_TASK1.csv")
print(task)
task = task.dropna()
task = task.drop_duplicates()
print(task)
# Out:
#              x0        x1
# 0      0.916471  0.371461
# 1      1.346079 -0.191338
# 2      1.264160 -0.307898
# 3     -0.567403  0.672286
# 4      1.554483 -0.445260
# ...         ...       ...
# 19995  1.094372  1.108952
# 19996  1.173998  1.184599
# 19997  1.189959  1.438640
# 19998  1.297661  1.288944
# 19999  1.069831  1.093519
#
# [20000 rows x 2 columns]
#              x0        x1
# 0      0.916471  0.371461
# 1      1.346079 -0.191338
# 2      1.264160 -0.307898
# 3     -0.567403  0.672286
# 4      1.554483 -0.445260
# ...         ...       ...
# 19995  1.094372  1.108952
# 19996  1.173998  1.184599
# 19997  1.189959  1.438640
# 19998  1.297661  1.288944
# 19999  1.069831  1.093519
#
# [20000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
X = task.iloc[:, 0].values.reshape(-1, 1)
Y = task.iloc[:, 1].values.reshape(-1, 1)
plt.scatter(X, Y, color='blue')
plt.show()

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps = 0.08, min_samples = 10)
X = task.iloc[:, 0:2].values.reshape(-1, 2)
y_pred = dbscan.fit_predict(X)
plt.title("eps = 0.08, min_samples = 10")
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

dbscan = DBSCAN(eps = 0.08)
X = task.iloc[:, 0:2].values.reshape(-1, 2)
y_pred = dbscan.fit_predict(X)
plt.title("eps = 0.08")
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()

dbscan = DBSCAN()
X = task.iloc[:, 0:2].values.reshape(-1, 2)
y_pred = dbscan.fit_predict(X)
plt.title("default parameter")
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.show()
